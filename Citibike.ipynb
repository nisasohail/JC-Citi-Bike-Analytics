# %%
import pandas as pd
import os

# %%
file_path1 = os.path.join("JC-201806-citibike-tripdata.csv")
file_path2 = os.path.join("JC-201807-citibike-tripdata.csv")
file_path3 = os.path.join("JC-201808-citibike-tripdata.csv")

# %%
df1 = pd.read_csv(file_path1)

# %%
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
df2 = pd.read_csv(file_path2)

# %%
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
df3 = pd.read_csv(file_path3)

# %%
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
dfall = pd.concat([df1,df2,df3])
dfall
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1               259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2               686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3               164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4               769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
# 5               256  2018-06-01 10:33:02.1100  2018-06-01 10:37:18.1230
# 6               267  2018-06-01 11:33:22.6440  2018-06-01 11:37:50.0350
# 7               258  2018-06-01 12:07:49.8830  2018-06-01 12:12:08.0190
# 8              1247  2018-06-01 12:53:24.8470  2018-06-01 13:14:11.8770
# 9               761  2018-06-01 13:21:09.2160  2018-06-01 13:33:50.9930
# 10              261  2018-06-01 13:29:55.8570  2018-06-01 13:34:17.5260
# 11              294  2018-06-01 13:54:32.1000  2018-06-01 13:59:26.7800
# ...

# %%
dfall.to_csv("citibike.csv")
